# %%
import pandas as pd

df = pd.read_csv("../data/raw/global_financial_markets_2000_Now.csv")
df.head()
# Out:
#          date        open        high         low       close      volume  \
# 0  2000-01-03   1469.2500   1478.0000   1438.3600   1455.2200   931800000
# 1  2000-01-03   4186.1899   4192.1899   3989.7100   4131.1499  1510070000
# 2  2000-01-03  17057.6992  17426.1602  17057.6992  17369.6309           0
# 3  2000-01-03      0.0098      0.0099      0.0097      0.0098           0
# 4  2000-01-03   5209.5400   5384.6602   5209.5400   5375.1099           0
#
#      symbol asset_name   asset_type  region
# 0     ^GSPC     S&P500  Stock Index  Global
# 1     ^IXIC     NASDAQ  Stock Index  Global
# 2      ^HSI        HSI  Stock Index  Global
# 3  JPYUSD=X    JPY/USD     Currency  Global
# 4    ^BSESN     SENSEX  Stock Index  Global
